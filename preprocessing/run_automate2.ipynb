# %%
from sklearn.datasets import load_iris
import pandas as pd
from joblib import dump, load
import numpy as np
from automate_Fathir_Maula_S_2 import preprocess_data
 
# Memuat dataset
data = pd.read_csv('../healthcare-dataset-stroke_raw.csv')
data.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
X_train, X_test, y_train, y_test = preprocess_data(data, 'stroke', 'preprocessor_pipeline.joblib', 'data.csv')
# Out:
# Nama kolom berhasil disimpan ke: data.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 X_train, X_test, y_train, y_test = preprocess_data(data, 'stroke', 'preprocessor_pipeline.joblib', 'data.csv')
#
# File c:\Users\ACER\Desktop\Eksperimen_SML_Fathir Maula. S\preprocessing\automate_Fathir_Maula_S_2.py:44, in preprocess_data(data, target_column, save_path, file_path)
#      36 numeric_transformer = Pipeline(steps=[
#      37     ('imputer', SimpleImputer(strategy='mean')),
#      38     ('scaler', StandardScaler())
#      39 ])
#      41 # Pipeline untuk fitur kategoris
#      42 categorical_transformer = Pipeline(steps=[
#      43     ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
# ---> 44     ('encoder', LabelEncoder(handle_unknown='ignore'))
#      45 ])
#      47 # Column Transformer
# ...
